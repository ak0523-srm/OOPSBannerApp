# %%
lst = [["Bangain","Aloo"],[1,True,2.5,3+2j]]
lst[0][1]
# Out:
# 'Aloo'

# %%
type(lst[1][3])
# Out:
# complex

# %%
shopping_lst=["potato","Apple",2,1,True]
for item in shopping_lst:
    print(item,end = " ")
# Out:
# potato Apple 2 1 True

# %%
2**3
# Out:
# 8
